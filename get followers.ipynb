# %%
from selenium import webdriver

# %%
import time

# %%
from selenium.webdriver.common.keys import Keys

# %%
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary

# %%
browser = webdriver.Firefox(executable_path='C:/Users/sep/Desktop/python/prj/anaconda/twitter/geckodriver.exe')

# %%
browser.get('https://twitter.com/login')

# %%
email = browser.find_elements_by_class_name('email-input')

# %%
email[1].clear()

# %%
email[1].send_keys('evgeniychan@gmail.com')

# %%
password = browser.find_element_by_class_name('js-password-field')

# %%
password.clear()

# %%
password.send_keys('32167chan')

# %%
password.send_keys(Keys.RETURN)

# %%
button = browser.find_elements_by_class_name('submit')

# %%
button[1].click()

# %%
browser.get('https://twitter.com/PLAYERUNKNOWN/followers')

# %%
followers = {}

# %%
names[-5:]
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="2ce2369b-1a24-4297-8223-5ed89cad37c4", element="42fedd2d-1ffb-46da-988a-776dca97363c")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="2ce2369b-1a24-4297-8223-5ed89cad37c4", element="61dae1cb-99f8-4d71-ab2c-3755508ded4a")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="2ce2369b-1a24-4297-8223-5ed89cad37c4", element="17fa757d-f365-4e15-a24e-2e7b71587694")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="2ce2369b-1a24-4297-8223-5ed89cad37c4", element="54e9f541-239c-4198-a1aa-f3a01b1b8329")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="2ce2369b-1a24-4297-8223-5ed89cad37c4", element="419eb6a1-e108-4962-b6c3-07c0b6425b5d")>]

# %%
def get_folowers():
    names = browser.find_elements_by_class_name("ProfileCard-userFields")
    for i in names[-10:]:
        for a in i.text.split():
            if a.startswith('@'):
                followers[a] = 0

# %%
def scroll_down():
    SCROLL_PAUSE_TIME = 1

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

# %%
for i in range(125):
    
    scroll_down()
    get_folowers()
    # %%time
# Out:
# Wall time: 0 ns
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-182-f553d67e6366> in <module>()
#       2
#       3     scroll_down()
# ----> 4     get_folowers()
#       5     get_ipython().run_line_magic('time', '')
#
# <ipython-input-175-6f6ac6dcf864> in get_folowers()
#       1 def get_folowers():
# ----> 2     names = browser.find_elements_by_class_name("ProfileCard-userFields")
#       3     for i in names[-10:]:
#       4         for a in i.text.split():
#       5             if a.startswith('@'):
#
# ~\AppData\Local\Continuum\anaconda3\envs\cntk\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_class_name(self, name)
#     569             elements = driver.find_elements_by_class_name('foo')
#     570         """
# --> 571         return self.find_elements(by=By.CLASS_NAME, value=name)
#     572
# ...

# %%
len(followers)
# Out:
# 1529

# %%
import pandas as pd

# %%
[i for i in followers]
# Out:
# ['@An7ero_official',
#  '@uroshsrb',
#  '@hotnokia_cs',
#  '@malpraxyz',
#  '@OriVaking',
#  '@Zer0cool_11',
#  '@Mathiis_',
#  '@BlastoBlazer',
#  '@Andy_Namite',
#  '@natthan_bruce',
#  '@mr_ram28',
#  '@AyzDaymon',
#  '@michellepq_pubg',
#  '@dzintarstraupe',
#  '@LLutd',
#  '@ilkaydnc',
#  '@manuel_breuern',
#  '@xDaZzzy',
#  '@Harryfantas',
#  '@Byssen_Ryssen',
#  '@aaronb198',
#  '@Omarpeace99',
#  '@Kalleee_k',
#  '@Matt41844434',
#  '@Cremonini',
#  '@AlmightySpeedy5',
#  '@MF_NTC',
#  '@JayLewt',
#  '@TioTheHunter',
#  '@blueliner46',
#  '@THICCSAUCES',
#  '@TashaTyson15',
#  '@OSGHQ]',
#  '@GRRL]',
#  '@aulrizky',
#  '@josegarciazav',
#  '@qal030327',
#  '@MarvinLorinoYT',
#  '@Kid_Oken',
#  '@timfletch17',
#  '@adamburke1234',
#  '@JesusEl92724814',
#  '@FoxCatPlayz',
#  '@u1sema',
#  '@mete90054581',
#  '@Skyshroud1',
#  '@DustDay01',
#  '@Nuitkii2',
#  '@renanmunarao',
#  '@arturomtzsegura',
#  '@Kicks58577508',
#  '@calebvane',
#  '@ImGalaxyLoL',
#  '@YaBoiEx_',
# ...

# %%
frame = pd.DataFrame([i for i in followers], header=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-6eeca0cf0e46> in <module>()
# ----> 1 frame = pd.DataFrame([i for i in followers], header=False)
#
# TypeError: __init__() got an unexpected keyword argument 'header'

# %%
frame = frame.rename(index=str, columns={0: "User"})

# %%
frame.to_excel('followers.xlsx')
